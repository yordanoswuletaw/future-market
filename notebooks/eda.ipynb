# %% [markdown]
# ### Read Data

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

src_dir = os.path.abspath(os.path.join('..', 'src'))
sys.path.append(src_dir)

import requests
import pandas as pd 

from utils.config import settings

# %%
# Read Data
data = requests.get(settings.URL)
data.json().keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (5min)'])

# %%
data = data.json()
data['Meta Data']
# Out:
# {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2025-03-13 19:55:00',
#  '4. Interval': '5min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
max(data['Time Series (5min)'].keys())
# Out:
# '2025-03-13 19:55:00'

# %%
data['Time Series (5min)']
# Out:
# {'2025-03-13 19:55:00': {'1. open': '246.4250',
#   '2. high': '246.8000',
#   '3. low': '246.4250',
#   '4. close': '246.5000',
#   '5. volume': '35'},
#  '2025-03-13 19:45:00': {'1. open': '247.0000',
#   '2. high': '247.0000',
#   '3. low': '246.8000',
#   '4. close': '247.0000',
#   '5. volume': '82'},
#  '2025-03-13 19:40:00': {'1. open': '247.2000',
#   '2. high': '247.2000',
#   '3. low': '247.2000',
#   '4. close': '247.2000',
#   '5. volume': '2'},
#  '2025-03-13 19:35:00': {'1. open': '247.0000',
#   '2. high': '247.3300',
#   '3. low': '247.0000',
#   '4. close': '247.3300',
#   '5. volume': '52'},
#  '2025-03-13 19:30:00': {'1. open': '246.8100',
#   '2. high': '246.8100',
#   '3. low': '246.8100',
#   '4. close': '246.8100',
#   '5. volume': '20'},
#  '2025-03-13 19:25:00': {'1. open': '246.8200',
#   '2. high': '247.3300',
#   '3. low': '246.8200',
#   '4. close': '247.3300',
#   '5. volume': '2'},
#  '2025-03-13 19:20:00': {'1. open': '247.0000',
# ...

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=WXL7EJZYMJTYU2A6'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': 'Generate Passive Income From This Low-Cost Vanguard ETF That Is Crushing the S&P 500 in 2025', 'url': 'https://www.fool.com/investing/2025/03/14/generate-passive-income-low-cost-vanguard-etf-buy/', 'time_published': '20250314T110700', 'authors': ['Daniel Foelber'], 'summary': "Investors typically turn to dividend-paying stocks and exchange-traded funds ( ETFs ) to boost their passive income streams so that their returns aren't solely tied to stock price gains. But so far this year, many value and income stocks have performed better than growth stocks.", 'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F810462%2Flaugh-smile-work-laptop-
# ...

# %%
data.keys()
# Out:
# dict_keys(['items', 'sentiment_score_definition', 'relevance_score_definition', 'feed'])

# %%
data['sentiment_score_definition']
# Out:
# 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish'

# %%
data['relevance_score_definition']
# Out:
# '0 < x <= 1, with a higher score indicating higher relevance.'

# %%
feeds = data['feed']
topics = [feed['topics'] for feed in feeds]
topics
# Out:
# [[{'topic': 'Financial Markets', 'relevance_score': '1.0'},
#   {'topic': 'Manufacturing', 'relevance_score': '0.5'},
#   {'topic': 'Earnings', 'relevance_score': '0.158519'},
#   {'topic': 'Technology', 'relevance_score': '0.5'}],
#  [{'topic': 'Technology', 'relevance_score': '0.5'},
#   {'topic': 'Financial Markets', 'relevance_score': '0.999974'},
#   {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#  [{'topic': 'Financial Markets', 'relevance_score': '0.161647'},
#   {'topic': 'Earnings', 'relevance_score': '0.360215'},
#   {'topic': 'Technology', 'relevance_score': '1.0'},
#   {'topic': 'Economy - Macro', 'relevance_score': '0.158519'}],
#  [{'topic': 'Financial Markets', 'relevance_score': '0.54554'},
#   {'topic': 'Manufacturing', 'relevance_score': '0.5'},
#   {'topic': 'Earnings', 'relevance_score': '0.614606'},
#   {'topic': 'Technology', 'relevance_score': '0.5'},
#   {'topic': 'Economy - Macro', 'relevance_score': '0.158519'}],
# ...

# %%
topics = set()
min_len = max_len = 6
for feed in feeds:
    min_len = min(min_len, len(feed['topics']))
    max_len = max(max_len, len(feed['topics']))
    for each in feed['topics']:
        topics.add(each['topic'])

print(min_len, max_len)
# Out:
# 1 6

# %%
topics
# Out:
# {'Earnings',
#  'Economy - Macro',
#  'Economy - Monetary',
#  'Energy & Transportation',
#  'Finance',
#  'Financial Markets',
#  'Life Sciences',
#  'Manufacturing',
#  'Real Estate & Construction',
#  'Retail & Wholesale',
#  'Technology'}

# %%
data
# Out:
# {'items': '50',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.',
#  'feed': [{'title': 'Generate Passive Income From This Low-Cost Vanguard ETF That Is Crushing the S&P 500 in 2025',
#    'url': 'https://www.fool.com/investing/2025/03/14/generate-passive-income-low-cost-vanguard-etf-buy/',
#    'time_published': '20250314T110700',
#    'authors': ['Daniel Foelber'],
#    'summary': "Investors typically turn to dividend-paying stocks and exchange-traded funds ( ETFs ) to boost their passive income streams so that their returns aren't solely tied to stock price gains. But so far this year, many value and income stocks have performed better than growth stocks.",
# ...

# %%
import os

# %%
os.cpu_count()
# Out:
# 4
